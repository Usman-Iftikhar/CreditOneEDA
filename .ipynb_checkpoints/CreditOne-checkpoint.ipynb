# %% [markdown]
# # Exploratory Data Analysis for Credit One
#
# ### Problem
# 1. Credit One is a credit rating service that is facing an increase in customer default rates
# 2. Revenue & customer loss and, eventually, loss of clients for Credit One
#
# ### Business Questions
# 1. How to ensure that customers can and will pay their loans?
# 2. Can this be done?

# %% [markdown]
# ### Notes on the credit dataset
# ###### Attributes
# * LIMIT_BAL: Amount of credit
# * SEX: 1=male; 2=female
# * EDUCATION: 1=graduate school; 2=university; 3=high school; 4,5,6,0=other
# * MARRIAGE: 1=married; 2=single, 3=divorce, 0=other
# * AGE: years
# * PAY_0 --> PAY_6: History of past payments from Sep, Aug, Jul, Jun, May, Apr 2005
#     * -2=no consumption;
#     * -1=paid in full
#     * 0=use of revolving credit
#     * 1=payment delay for 1 month
#     * 2=payment delay for 2 months
#     * 9=payment delay for 9 months
# * BILL_AMT1 --> BILL_AMT6: Amount of bill statement from Sep, Aug, Jul, Jun, May, Apr 2005
# * PAY_AMT1 --> PAY_AMT6: Amount of previous statement from Sep, Aug, Jul, Jun, May, Apr 2005
# * default payment next month: Client's behavior
#     * 0=not default
#     * 1=default

# %%
# Import libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.feature_selection import VarianceThreshold, RFE, f_regression
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import MinMaxScaler

# %%
# Autocomplete methods
# %config IPCompleter.greedy=True

# %% [markdown]
# ###### Import data

# %%
credit = pd.read_csv('default of credit card clients.csv', header = 1)
credit.shape
# Out:
# (30000, 25)

# %% [markdown]
# ###### View data

# %%
# View data

credit.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...          0          0          0         0       689         0
# 1  ...       3272       3455       3261         0      1000      1000
# 2  ...      14331      14948      15549      1518      1500      1000
# 3  ...      28314      28959      29547      2000      2019      1200
# 4  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# ...

# %%
# Understand the makeup of the data (summary)

credit.describe()
# Out:
#                  ID       LIMIT_BAL           SEX     EDUCATION      MARRIAGE  \
# count  30000.000000    30000.000000  30000.000000  30000.000000  30000.000000
# mean   15000.500000   167484.322667      1.603733      1.853133      1.551867
# std     8660.398374   129747.661567      0.489129      0.790349      0.521970
# min        1.000000    10000.000000      1.000000      0.000000      0.000000
# 25%     7500.750000    50000.000000      1.000000      1.000000      1.000000
# 50%    15000.500000   140000.000000      2.000000      2.000000      2.000000
# 75%    22500.250000   240000.000000      2.000000      2.000000      2.000000
# max    30000.000000  1000000.000000      2.000000      6.000000      3.000000
#
#                 AGE         PAY_0         PAY_2         PAY_3         PAY_4  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      35.485500     -0.016700     -0.133767     -0.166200     -0.220667
# ...

# %% [markdown]
# What are the negative bill amounts (shown under minimum)?

# %% [markdown]
# ###### Check for missing values

# %%
credit.isnull().any()
# Out:
# ID                            False
# LIMIT_BAL                     False
# SEX                           False
# EDUCATION                     False
# MARRIAGE                      False
# AGE                           False
# PAY_0                         False
# PAY_2                         False
# PAY_3                         False
# PAY_4                         False
# PAY_5                         False
# PAY_6                         False
# BILL_AMT1                     False
# BILL_AMT2                     False
# BILL_AMT3                     False
# BILL_AMT4                     False
# BILL_AMT5                     False
# BILL_AMT6                     False
# PAY_AMT1                      False
# PAY_AMT2                      False
# PAY_AMT3                      False
# PAY_AMT4                      False
# PAY_AMT5                      False
# PAY_AMT6                      False
# default payment next month    False
# dtype: bool

# %% [markdown]
# ###### Check the data types of each variable

# %%
credit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
# ID                            30000 non-null int64
# LIMIT_BAL                     30000 non-null int64
# SEX                           30000 non-null int64
# EDUCATION                     30000 non-null int64
# MARRIAGE                      30000 non-null int64
# AGE                           30000 non-null int64
# PAY_0                         30000 non-null int64
# PAY_2                         30000 non-null int64
# PAY_3                         30000 non-null int64
# PAY_4                         30000 non-null int64
# PAY_5                         30000 non-null int64
# PAY_6                         30000 non-null int64
# BILL_AMT1                     30000 non-null int64
# BILL_AMT2                     30000 non-null int64
# BILL_AMT3                     30000 non-null int64
# BILL_AMT4                     30000 non-null int64
# ...

# %% [markdown]
# ###### Get rows and columns for the dataset

# %%
print('Indicies are:', credit.index)
print()
print('Columns are:', credit.columns)
# Out:
# Indicies are: RangeIndex(start=0, stop=30000, step=1)
#
# Columns are: Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='object')

# %% [markdown]
# ## Visualize Data

# %% [markdown]
# #### Histogram

# %%
plt.hist(credit['LIMIT_BAL'], bins=20)
plt.xlabel('Amount $')
plt.ylabel('Count')
plt.title('Limit Balance Distribution')
plt.show()

# %%
plt.hist(credit['AGE'], bins=20)
plt.xlabel('Age Years')
plt.ylabel('Count')
plt.title('Age Distribution')
plt.show()

# %%
# Same histogram without using the Matplotlib.
# credit.hist(column = 'AGE', bins=20, grid=False)

# %% [markdown]
# #### Line Plots

# %%
plt.plot(credit['LIMIT_BAL'])
plt.show()

# %% [markdown]
# #### Scatter Plots

# %%
plt.scatter(credit['PAY_0'], credit['PAY_2'])
plt.show()

# %% [markdown]
# #### Box Plots

# %%
plt.boxplot(credit['BILL_AMT1'], 0, 'gD')
plt.show()

# %% [markdown]
# #### Correlation

# %%
corrMat = credit.corr()
print(corrMat)
# Out:
#                                   ID  LIMIT_BAL       SEX  EDUCATION  \
# ID                          1.000000   0.026179  0.018497   0.039177
# LIMIT_BAL                   0.026179   1.000000  0.024755  -0.219161
# SEX                         0.018497   0.024755  1.000000   0.014232
# EDUCATION                   0.039177  -0.219161  0.014232   1.000000
# MARRIAGE                   -0.029079  -0.108139 -0.031389  -0.143464
# AGE                         0.018678   0.144713 -0.090874   0.175061
# PAY_0                      -0.030575  -0.271214 -0.057643   0.105364
# PAY_2                      -0.011215  -0.296382 -0.070771   0.121566
# PAY_3                      -0.018494  -0.286123 -0.066096   0.114025
# PAY_4                      -0.002735  -0.267460 -0.060173   0.108793
# PAY_5                      -0.022199  -0.249411 -0.055064   0.097520
# PAY_6                      -0.020270  -0.235195 -0.044008   0.082316
# BILL_AMT1                   0.019389   0.285430 -0.033642   0.023581
# ...

# %%
# plt.figure(figsize=(25,25)) 
# play with the figsize until the plot is big enough to plot all the columns
# of your dataset, or the way you desire it to look like otherwise

sns.heatmap(credit.corr())

# %% [markdown]
# #### Covariance

# %%
covMat = credit.cov()
print(covMat)
# Out:
#                                       ID     LIMIT_BAL          SEX  \
# ID                          7.500250e+07  2.941664e+07    78.356379
# LIMIT_BAL                   2.941664e+07  1.683446e+10  1571.050630
# SEX                         7.835638e+01  1.571051e+03     0.239247
# EDUCATION                   2.681543e+02 -2.247403e+04     0.005502
# MARRIAGE                   -1.314525e+02 -7.323670e+03    -0.008014
# AGE                         1.491057e+03  1.730767e+05    -0.409726
# PAY_0                      -2.975726e+02 -3.954593e+04    -0.031685
# PAY_2                      -1.162770e+02 -4.603765e+04    -0.041442
# PAY_3                      -1.916922e+02 -4.443225e+04    -0.038694
# PAY_4                      -2.769132e+01 -4.057181e+04    -0.034411
# PAY_5                      -2.178600e+02 -3.667056e+04    -0.030521
# PAY_6                      -2.018774e+02 -3.509308e+04    -0.024754
# BILL_AMT1                   1.236447e+07  2.727020e+09 -1211.694332
# ...

# %%
sns.heatmap(credit.cov())

# %% [markdown]
# #### Marriage data

# %%
credit.groupby('MARRIAGE')['MARRIAGE'].count()
# Out:
# MARRIAGE
# 0       54
# 1    13659
# 2    15964
# 3      323
# Name: MARRIAGE, dtype: int64

# %%
# marriage_status = sns.factorplot('MARRIAGE', data = credit, kind='count', aspect=1.5)
marriage_status = sns.catplot('MARRIAGE', data = credit, kind='count', aspect=1)

# %% [markdown]
# #### Education data

# %%
edu_status = sns.catplot('EDUCATION', data = credit, kind='count', aspect=2)

# %%
mar_edu = sns.catplot('EDUCATION',
                      data = credit, 
                      hue='MARRIAGE', 
                      kind='count', 
                      aspect=3)

# %%
# Number of defaulted in each marriage group, grouped by education.
# Total was found for each marriage group, grouped by education using margins=True.
credit.pivot_table('default payment next month', 'EDUCATION', 'MARRIAGE', aggfunc=np.sum, margins=True)
# Out:
# MARRIAGE     0       1       2     3   All
# EDUCATION
# 0          NaN     0.0     0.0   NaN     0
# 1          0.0   769.0  1254.0  13.0  2036
# 2          1.0  1666.0  1619.0  44.0  3330
# 3          4.0   754.0   452.0  27.0  1237
# 4          NaN     3.0     4.0   0.0     7
# 5          NaN     9.0     9.0   0.0    18
# 6          NaN     5.0     3.0   0.0     8
# All        5.0  3206.0  3341.0  84.0  6636

# %%
# Create a DF for 'not default' and create a pivot.
not_default = credit[credit['default payment next month'] == 0]
not_default.pivot_table('default payment next month', 'EDUCATION', 'MARRIAGE', aggfunc=len, margins=True)
# Out:
# MARRIAGE      0        1        2      3    All
# EDUCATION
# 0           NaN      4.0     10.0    NaN     14
# 1           4.0   2953.0   5555.0   37.0   8549
# 2           5.0   5176.0   5401.0  118.0  10700
# 3          40.0   2107.0   1457.0   76.0   3680
# 4           NaN     49.0     64.0    3.0    116
# 5           NaN    141.0    118.0    3.0    262
# 6           NaN     23.0     18.0    2.0     43
# All        49.0  10453.0  12623.0  239.0  23364

# %% [markdown]
# ##### How many are at default and how many are not?

# %%
credit.groupby('default payment next month')['default payment next month'].count()
# Out:
# default payment next month
# 0    23364
# 1     6636
# Name: default payment next month, dtype: int64

# %%
default_status = sns.catplot('default payment next month', data = credit, kind='count', aspect=1)

# %% [markdown]
# #### Gender

# %%
gender_status = sns.catplot('SEX', data = credit, kind='count', aspect=1)

# %%
credit.pivot_table('default payment next month', 'SEX', 'EDUCATION', aggfunc=np.sum, margins=True)
# Out:
# EDUCATION  0     1     2     3  4   5  6   All
# SEX
# 1          0   906  1408   545  4   6  4  2873
# 2          0  1130  1922   692  3  12  4  3763
# All        0  2036  3330  1237  7  18  8  6636

# %%
gender_default = sns.catplot('SEX',
                             data = credit,
                             hue='default payment next month',
                             kind='count',
                             aspect=3)

# %%
gender_edu = sns.catplot('SEX',
                         data = credit,
                         hue='EDUCATION',
                         kind='count',
                         aspect=3)

# %% [markdown]
# #### Age

# %%
print('Average and median age of clients are %0.f and %0.f years old, respectively'%
      (credit.AGE.mean(),
       credit.AGE.median()))
# Out:
# Average and median age of clients are 35 and 34 years old, respectively

# %%
age_dist = sns.distplot(credit['AGE'])
age_dist.set_title("Distribution of Clients' Ages")
oldest = credit['AGE'].max()
youngest = credit['AGE'].min()
age_dist.set(xlim=(youngest,oldest))
# Out:
# [(21, 79)]

# %% [markdown]
# #### kde plot, Distribution of Passengers' Ages

# %%
fig = sns.FacetGrid(credit, hue='SEX', aspect=4)
fig.map(sns.kdeplot, 'AGE', shade=True)
fig.set(xlim=(0,oldest))
fig.set(title="Distribution of Age Grouped by Gender")
fig.add_legend()

# %% [markdown]
# #### Balance limit

# %%
print('The average balance is %0.f and the median balance is %0.f.'%
      (credit.LIMIT_BAL.mean(),
       credit.LIMIT_BAL.median()))
# Out:
# The average balance is 167484 and the median balance is 140000.

# %%
bal_dist = sns.distplot(credit['LIMIT_BAL'])
bal_dist.set_title("Distribution of Clients' Balance")
max_bal = credit['LIMIT_BAL'].max()
bal_dist.set(xlim=(0,max_bal))
# Out:
# [(0, 1000000)]

# %% [markdown]
# #### Payments and bill amounts

# %%
credit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
# ID                            30000 non-null int64
# LIMIT_BAL                     30000 non-null int64
# SEX                           30000 non-null int64
# EDUCATION                     30000 non-null int64
# MARRIAGE                      30000 non-null int64
# AGE                           30000 non-null int64
# PAY_0                         30000 non-null int64
# PAY_2                         30000 non-null int64
# PAY_3                         30000 non-null int64
# PAY_4                         30000 non-null int64
# PAY_5                         30000 non-null int64
# PAY_6                         30000 non-null int64
# BILL_AMT1                     30000 non-null int64
# BILL_AMT2                     30000 non-null int64
# BILL_AMT3                     30000 non-null int64
# BILL_AMT4                     30000 non-null int64
# ...

# %%
plt.scatter(credit['PAY_0'], credit['LIMIT_BAL'])
plt.show()

# %%
credit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
# ID                            30000 non-null int64
# LIMIT_BAL                     30000 non-null int64
# SEX                           30000 non-null int64
# EDUCATION                     30000 non-null int64
# MARRIAGE                      30000 non-null int64
# AGE                           30000 non-null int64
# PAY_0                         30000 non-null int64
# PAY_2                         30000 non-null int64
# PAY_3                         30000 non-null int64
# PAY_4                         30000 non-null int64
# PAY_5                         30000 non-null int64
# PAY_6                         30000 non-null int64
# BILL_AMT1                     30000 non-null int64
# BILL_AMT2                     30000 non-null int64
# BILL_AMT3                     30000 non-null int64
# BILL_AMT4                     30000 non-null int64
# ...

# %%
# pd.tools.plotting.scatter_matrix(credit.loc[:, "PAY_0":"PAY_6"], diagonal="kde")
# plt.tight_layout()
# plt.show()
credit_pay = credit.loc[:,'PAY_0':'PAY_6']
sns.pairplot(credit_pay, kind="reg")
plt.show()

# %% [markdown]
# * Rarely are the payments delayed by 1 month
# * Majority are in revolving credit

# %%
credit_billAmt = credit.loc[:,'BILL_AMT1':'BILL_AMT6']
sns.pairplot(credit_billAmt, kind="reg")
plt.show()

# %%
sns.lmplot("PAY_AMT1", "BILL_AMT1", credit, hue="PAY_0", fit_reg=False)
sns.lmplot("PAY_AMT1", "BILL_AMT1", credit, hue="PAY_2", fit_reg=False)
sns.lmplot("PAY_AMT1", "BILL_AMT1", credit, hue="PAY_3", fit_reg=False)
sns.lmplot("PAY_AMT1", "BILL_AMT1", credit, hue="PAY_4", fit_reg=False)
sns.lmplot("PAY_AMT1", "BILL_AMT1", credit, hue="PAY_5", fit_reg=False)
sns.lmplot("PAY_AMT1", "BILL_AMT1", credit, hue="PAY_6", fit_reg=False)

# %%
ax = credit[["LIMIT_BAL"]].plot()
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5));

# %% [markdown]
# #### Bill amounts

# %%
ax = credit[["BILL_AMT1","BILL_AMT2","BILL_AMT3","BILL_AMT4","BILL_AMT5","BILL_AMT6"]].plot()
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5));

# %% [markdown]
# Notice Bill_amt3 is significantly higher than the limit balance.

# %% [markdown]
# #### Payment amounts

# %%
ax = credit[["PAY_AMT1","PAY_AMT2","PAY_AMT3","PAY_AMT4","PAY_AMT5","PAY_AMT6"]].plot()
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5));

# %% [markdown]
# Notice the pay_amt2 is significantly higher than the bill amount or the balance amount.

# %% [markdown]
# ### Factors Affecting the Default

# %%
credit.columns = credit.columns.str.replace(' ', '_')

# %%
credit['Default'] = credit.default_payment_next_month.map({0:"No", 1:"Yes"})

# %%
credit.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  \
# 0  ...          0          0         0       689         0         0
# 1  ...       3455       3261         0      1000      1000      1000
# 2  ...      14948      15549      1518      1500      1000      1000
# 3  ...      28959      29547      2000      2019      1200      1100
# 4  ...      19146      19131      2000     36681     10000      9000
#
#    PAY_AMT5  PAY_AMT6  default_payment_next_month  Default
# ...

# %% [markdown]
# ###### Default vs. education

# %%
sns.factorplot('EDUCATION','default_payment_next_month', hue='SEX', data = credit)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %% [markdown]
# From the figure above, individuals with university or high school education have a higher chance of defaulting than graduate school education

# %%
sns.catplot('Default', data=credit, hue='EDUCATION', kind='count', col='SEX')

# %% [markdown]
# #### Age Factor

# %%
# Linear plot of age vs. default
sns.lmplot('AGE', 'default_payment_next_month', data=credit, hue='SEX')

# %% [markdown]
# Figure above shows the linear trend of defaults is higher in male population than female population as the age increases.

# %%
# Default vs. Age grouped by marriage
sns.lmplot('AGE', 'default_payment_next_month', hue='MARRIAGE', data=credit)

# %% [markdown]
# Figure above shows chance of default is higher with age for divorced (3) individual compared to married (1) individuals where as it decreases for single (2) individuals with age.

# %% [markdown]
# ## Preprocess after EDA
# * Remove ID column
# * Replace white space in columns name with '_'
# * Recode values in education (0,4,5,6 as 0 -> other)
# * Convert 'default_payment_next_month' to categorical variable
# * Recode 'default_payment_next_month'; 0=Not Default, 1=Default
# * Descritize age?

# %%
# Copy the dataframe to start preprocessing

credit_ready = credit.copy(deep=True)

# %%
# Delete ID column

del credit_ready['ID']
del credit_ready['Default']

# %%
# Replace white space in columns name with '_'

credit_ready.columns = credit_ready.columns.str.replace(' ', '_')

# %%
# Recode values in education column

credit_ready['EDUCATION'] = credit_ready['EDUCATION'].replace([0, 4, 5, 6], 0)

# %%
credit_ready['EDUCATION'].describe()
# Out:
# count    30000.000000
# mean         1.779867
# std          0.728486
# min          0.000000
# 25%          1.000000
# 50%          2.000000
# 75%          2.000000
# max          3.000000
# Name: EDUCATION, dtype: float64

# %%
# Convert last column to categorical

credit_ready['default_payment_next_month'] = pd.Categorical(credit_ready['default_payment_next_month'])
credit_ready.default_payment_next_month.dtype
# Out:
# CategoricalDtype(categories=[0, 1], ordered=False)

# %%
# Recode categorical variables

credit_ready['default_payment_next_month'] = credit_ready['default_payment_next_month'].replace(0,'Not Default')
credit_ready['default_payment_next_month'] = credit_ready['default_payment_next_month'].replace(1,'Default')

# %%
credit_ready.head()
# Out:
#    LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0      20000    2          2         1   24      2      2     -1     -1
# 1     120000    2          2         2   26     -1      2      0      0
# 2      90000    2          2         2   34      0      0      0      0
# 3      50000    2          2         1   37      0      0      0      0
# 4      50000    1          2         1   57     -1      0     -1      0
#
#    PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0     -2  ...          0          0          0         0       689         0
# 1      0  ...       3272       3455       3261         0      1000      1000
# 2      0  ...      14331      14948      15549      1518      1500      1000
# 3      0  ...      28314      28959      29547      2000      2019      1200
# 4      0  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default_payment_next_month
# ...

# %% [markdown]
# ### Feature Selection: Remove highly correlated variables

# %%
# Identify correlation matrix
credit_ready_CorMat = credit_ready.corr().abs()


# Select upper triangle of correlation matrix
upper = credit_ready_CorMat.where(np.triu(np.ones(credit_ready_CorMat.shape), k=1).astype(np.bool))


# Find index of feature columns with correlation greater than 0.9.
to_drop = [column for column in upper.columns if any(upper[column]>0.9)]

# %%
# Drop highly correlated featrues.

credit_cor = credit_ready.drop(credit_ready[to_drop],axis=1)
credit_cor.head()
# Out:
#    LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0      20000    2          2         1   24      2      2     -1     -1
# 1     120000    2          2         2   26     -1      2      0      0
# 2      90000    2          2         2   34      0      0      0      0
# 3      50000    2          2         1   37      0      0      0      0
# 4      50000    1          2         1   57     -1      0     -1      0
#
#    PAY_5  PAY_6  BILL_AMT1  PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  \
# 0     -2     -2       3913         0       689         0         0         0
# 1      0      2       2682         0      1000      1000      1000         0
# 2      0      0      29239      1518      1500      1000      1000      1000
# 3      0      0      46990      2000      2019      1200      1100      1069
# 4      0      0       8617      2000     36681     10000      9000       689
#
#    PAY_AMT6 default_payment_next_month
# ...

# %% [markdown]
# ### Feature Selection: Near zero variance

# %%
credit_ready.head()
# Out:
#    LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0      20000    2          2         1   24      2      2     -1     -1
# 1     120000    2          2         2   26     -1      2      0      0
# 2      90000    2          2         2   34      0      0      0      0
# 3      50000    2          2         1   37      0      0      0      0
# 4      50000    1          2         1   57     -1      0     -1      0
#
#    PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0     -2  ...          0          0          0         0       689         0
# 1      0  ...       3272       3455       3261         0      1000      1000
# 2      0  ...      14331      14948      15549      1518      1500      1000
# 3      0  ...      28314      28959      29547      2000      2019      1200
# 4      0  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default_payment_next_month
# ...

# %%
# Create features and target

credit_nzv = credit_ready.iloc[:, 0:23]
credit_nzv_target = credit_ready.iloc[:, -1]

# %%
credit_nzv
# Out:
#        LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0          20000    2          2         1   24      2      2     -1     -1
# 1         120000    2          2         2   26     -1      2      0      0
# 2          90000    2          2         2   34      0      0      0      0
# 3          50000    2          2         1   37      0      0      0      0
# 4          50000    1          2         1   57     -1      0     -1      0
# 5          50000    1          1         2   37      0      0      0      0
# 6         500000    1          1         2   29      0      0      0      0
# 7         100000    2          2         2   23      0     -1     -1      0
# 8         140000    2          3         1   28      0      0      2      0
# 9          20000    1          3         2   35     -2     -2     -2     -2
# 10        200000    2          3         2   34      0      0      2      0
# ...

# %%
credit_nzv_target
# Out:
# 0            Default
# 1            Default
# 2        Not Default
# 3        Not Default
# 4        Not Default
# 5        Not Default
# 6        Not Default
# 7        Not Default
# 8        Not Default
# 9        Not Default
# 10       Not Default
# 11       Not Default
# 12       Not Default
# 13           Default
# 14       Not Default
# 15       Not Default
# 16           Default
# 17       Not Default
# 18       Not Default
# 19       Not Default
# 20       Not Default
# 21           Default
# 22           Default
# 23           Default
# 24       Not Default
# 25       Not Default
# 26           Default
# 27       Not Default
# 28       Not Default
# 29       Not Default
#             ...
# 29970    Not Default
# 29971    Not Default
# 29972    Not Default
# 29973        Default
# 29974        Default
# 29975    Not Default
# 29976        Default
# 29977    Not Default
# 29978    Not Default
# 29979    Not Default
# 29980    Not Default
# 29981    Not Default
# ...

# %%
# Create VarianceThreshold object with a variance with a threshold of 0.5

thresholder = VarianceThreshold()

# %%
# Apply the threshold filter to the data set X

thresholder.fit(credit_nzv)
# Out:
# VarianceThreshold(threshold=0.0)

# %%
# Get all the features that are not constant

var_col = len(credit_nzv.columns[thresholder.get_support()])

# %%
# # list of all the column that are above the threshold

var_col
# Out:
# 23

# %%
# Get the number of constant features

const_col = [column for column in credit_nzv.columns
            if column not in credit_nzv.columns[thresholder.get_support()]]
print(len(const_col))
# Out:
# 0

# %% [markdown]
# None of the columns have near zero variance.
#
# For the sake of this exercise, below code shows how to remove the columns that would have near zero variance.

# %%
credit_nzv = thresholder.transform(credit_nzv)
credit_nzv.shape
# Out:
# (30000, 23)

# %%
credit_nzv_target.shape
# Out:
# (30000,)
